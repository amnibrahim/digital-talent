# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
#
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
import random

# %%
nilai = []

for i in range(0,250):
    nilai.append(random.randrange(0,100))
print('jumlah',len(nilai))
print(nilai[:50])
# Out:
# ('jumlah', 250)
# [42, 75, 60, 88, 14, 51, 42, 93, 84, 57, 64, 8, 80, 90, 94, 89, 94, 42, 70, 23, 6, 92, 62, 37, 0, 1, 55, 38, 59, 70, 49, 17, 0, 95, 3, 2, 62, 52, 5, 32, 80, 39, 55, 62, 65, 60, 84, 75, 9, 86]

# %%
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut

for i in nilai:
    if i % 2 == 1:
        print(i)
# Out:
# 75
# 51
# 93
# 57
# 89
# 23
# 37
# 1
# 55
# 59
# 49
# 17
# 95
# 3
# 5
# 39
# 55
# 65
# 75
# 9
# 97
# 3
# 15
# 77
# 59
# 39
# 17
# 37
# 31
# 43
# 43
# 59
# 85
# 35
# 33
# 29
# 91
# 37
# 85
# 73
# 93
# 9
# 7
# 77
# 13
# 93
# 47
# 41
# 91
# 11
# 71
# 47
# 91
# 41
# 47
# 21
# 91
# 11
# 83
# 55
# 87
# 23
# 63
# 99
# 91
# 59
# 11
# 79
# 9
# 31
# 31
# 71
# 77
# 45
# 55
# 85
# 7
# 5
# 67
# 71
# 43
# 69
# 79
# 31
# 45
# 41
# 61
# 1
# 43
# 33
# 51
# 33
# 55
# 79
# 91
# 77
# 91
# 15
# 15
# 1
# 7
# 15
# 15
# 47
# 13
# 67
# 9
# 29
# 65
# 71
# 85
# 13
# 39
# 81
# 85
# 33
# 95
# 51
# 59

# %%
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70

for i in nilai:
    if i > 70:
        print(i)
# Out:
# 75
# 88
# 93
# 84
# 80
# 90
# 94
# 89
# 94
# 92
# 95
# 80
# 84
# 75
# 86
# 97
# 77
# 80
# 98
# 92
# 85
# 91
# 72
# 86
# 78
# 85
# 73
# 76
# 93
# 96
# 77
# 93
# 86
# 91
# 71
# 91
# 74
# 91
# 84
# 82
# 83
# 90
# 87
# 84
# 76
# 99
# 91
# 79
# 96
# 71
# 77
# 92
# 85
# 98
# 71
# 79
# 94
# 90
# 88
# 79
# 72
# 91
# 72
# 98
# 77
# 91
# 82
# 76
# 86
# 71
# 85
# 92
# 94
# 81
# 82
# 85
# 72
# 95
# 94
# 86

# %%
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut

total = 0.0

for i in nilai:
    total = total + i
mean = total / len(nilai)
print("mean", mean)

substract = []
temp = 0

for i in nilai:
    j = (i - mean)**2
    substract.append(j)
    temp = temp + j
    
stdev = math.sqrt(temp / len(nilai))
print("stdev", stdev)
# Out:
# ('mean', 50.58)
# ('stdev', 29.659595411940472)

# %%
# 3. Tampilkan nilai maksimum dan minimum

max_temp = 0
min_temp = 1

for i in nilai:
    if i > max_temp:
        max_temp = i
    elif i <= min_temp:
        min_temp = i

print('nilai maksimum',max_temp)
print('nilai minimum',min_temp)
# Out:
# ('nilai maksimum', 99)
# ('nilai minimum', 0)

# %%
# 4. Tampilkan modus dari sekumpulan nilai tersebut

dict = {}

for i in nilai:
    if i in dict:
        dict[i] += 1
    else:
        dict[i] = 1

temp = 0
mode = 0
for k,v in dict.items():
    if v > temp:
        temp = v
        mode = k
    print(k,v)
        
print('modus',mode,'dengan jumlah sebanyak',temp)
# Out:
# (0, 3)
# (1, 3)
# (2, 1)
# (3, 2)
# (4, 3)
# (5, 2)
# (6, 4)
# (7, 3)
# (8, 5)
# (9, 4)
# (10, 1)
# (11, 3)
# (12, 1)
# (13, 3)
# (14, 5)
# (15, 5)
# (16, 4)
# (17, 2)
# (18, 2)
# (20, 2)
# (21, 1)
# (22, 1)
# (23, 2)
# (24, 2)
# (26, 1)
# (28, 1)
# (29, 2)
# (30, 3)
# (31, 4)
# (32, 1)
# (33, 4)
# (34, 3)
# (35, 1)
# (36, 1)
# (37, 3)
# (38, 2)
# (39, 3)
# (40, 4)
# (41, 3)
# (42, 5)
# (43, 4)
# (44, 1)
# (45, 2)
# (46, 1)
# (47, 4)
# (48, 2)
# (49, 1)
# (50, 3)
# (51, 3)
# (52, 3)
# (55, 5)
# (56, 3)
# (57, 1)
# (58, 1)
# (59, 5)
# (60, 5)
# (61, 1)
# (62, 3)
# (63, 1)
# (64, 3)
# (65, 2)
# (66, 4)
# (67, 2)
# (68, 2)
# (69, 1)
# (70, 2)
# (71, 4)
# (72, 4)
# (73, 1)
# (74, 1)
# (75, 2)
# (76, 3)
# (77, 4)
# (78, 1)
# (79, 3)
# (80, 3)
# (81, 1)
# (82, 3)
# (83, 1)
# (84, 4)
# (85, 5)
# (86, 5)
# (87, 1)
# (88, 2)
# (89, 1)
# (90, 3)
# (91, 7)
# (92, 4)
# (93, 3)
# (94, 5)
# (95, 2)
# (96, 2)
# (97, 1)
# (98, 3)
# (99, 1)
# ('modus', 91, 'dengan jumlah sebanyak', 7)

# %% [markdown]
# # LATIHAN 3 - Word Count
#
# Diberikan sebuah paragraf, hitunglah banyak kemunculan masing-masing kata. Contoh : "Presiden pagi ini melakukan kunjungan ke Jogja"
#
# - presiden: 1
# - pagi: 1
# - ini: 1
# - melakukan: 1
# - kunjungan: 1
# - ke: 1
# - jogja: 1
#
# hints: Gunakan Dictionary dalam menyimpan word count. Gunakan kata sebagai key, dan jumlah kemunculan sebagai value

# %%
paragraf = "Barcelona berhasil merebut posisi puncak klasemen La Liga Spanyol seusai menang 4-2 atas Sevilla pada pertandingan pekan kesembilan di Stadion Camp Nou, Sabtu (20/10/2018) atau Minggu dini hari WIB. Barcelona membuka keunggulan pada menit ke-2 melalui gol yang dicetak oleh Philippe Coutinho. Lionel Messi menggandakan keunggulan Barcelona, 10 menit berselang.  Namun, nahas bagi Barcelona, karena Messi harus ditarik keluar pada menit ke-26 setelah mengalami cedera. Tanpa Messi, skor 2-0 bertahan hingga babak pertama berakhir."
print(paragraf)
# Out:
# Barcelona berhasil merebut posisi puncak klasemen La Liga Spanyol seusai menang 4-2 atas Sevilla pada pertandingan pekan kesembilan di Stadion Camp Nou, Sabtu (20/10/2018) atau Minggu dini hari WIB. Barcelona membuka keunggulan pada menit ke-2 melalui gol yang dicetak oleh Philippe Coutinho. Lionel Messi menggandakan keunggulan Barcelona, 10 menit berselang.  Namun, nahas bagi Barcelona, karena Messi harus ditarik keluar pada menit ke-26 setelah mengalami cedera. Tanpa Messi, skor 2-0 bertahan hingga babak pertama berakhir.

# %%
paragraf = paragraf.replace('(','').replace(')','').replace('/',' ').replace('-',' ').replace('.','').replace(',','').lower()
print(paragraf)
# Out:
# barcelona berhasil merebut posisi puncak klasemen la liga spanyol seusai menang 4 2 atas sevilla pada pertandingan pekan kesembilan di stadion camp nou sabtu 20 10 2018 atau minggu dini hari wib barcelona membuka keunggulan pada menit ke 2 melalui gol yang dicetak oleh philippe coutinho lionel messi menggandakan keunggulan barcelona 10 menit berselang  namun nahas bagi barcelona karena messi harus ditarik keluar pada menit ke 26 setelah mengalami cedera tanpa messi skor 2 0 bertahan hingga babak pertama berakhir

# %%
list_paragraf = paragraf.split()
print(list_paragraf)
print('jumlah',len(list_paragraf))
# Out:
# ['barcelona', 'berhasil', 'merebut', 'posisi', 'puncak', 'klasemen', 'la', 'liga', 'spanyol', 'seusai', 'menang', '4', '2', 'atas', 'sevilla', 'pada', 'pertandingan', 'pekan', 'kesembilan', 'di', 'stadion', 'camp', 'nou', 'sabtu', '20', '10', '2018', 'atau', 'minggu', 'dini', 'hari', 'wib', 'barcelona', 'membuka', 'keunggulan', 'pada', 'menit', 'ke', '2', 'melalui', 'gol', 'yang', 'dicetak', 'oleh', 'philippe', 'coutinho', 'lionel', 'messi', 'menggandakan', 'keunggulan', 'barcelona', '10', 'menit', 'berselang', 'namun', 'nahas', 'bagi', 'barcelona', 'karena', 'messi', 'harus', 'ditarik', 'keluar', 'pada', 'menit', 'ke', '26', 'setelah', 'mengalami', 'cedera', 'tanpa', 'messi', 'skor', '2', '0', 'bertahan', 'hingga', 'babak', 'pertama', 'berakhir']
# ('jumlah', 80)

# %%
dict_paragraf = {}

for i in list_paragraf:
    if i not in dict_paragraf:
        dict_paragraf[i] = 1
    else:
        dict_paragraf[i] += 1
    
for k,v in dict_paragraf.items():
    print(k,v)
# Out:
# ('pada', 3)
# ('posisi', 1)
# ('berselang', 1)
# ('liga', 1)
# ('hari', 1)
# ('messi', 3)
# ('sevilla', 1)
# ('2018', 1)
# ('dini', 1)
# ('keunggulan', 2)
# ('puncak', 1)
# ('nou', 1)
# ('mengalami', 1)
# ('minggu', 1)
# ('kesembilan', 1)
# ('pertandingan', 1)
# ('gol', 1)
# ('menit', 3)
# ('stadion', 1)
# ('20', 1)
# ('la', 1)
# ('setelah', 1)
# ('di', 1)
# ('harus', 1)
# ('menang', 1)
# ('dicetak', 1)
# ('cedera', 1)
# ('0', 1)
# ('ditarik', 1)
# ('2', 3)
# ('4', 1)
# ('babak', 1)
# ('bagi', 1)
# ('berakhir', 1)
# ('sabtu', 1)
# ('skor', 1)
# ('philippe', 1)
# ('hingga', 1)
# ('spanyol', 1)
# ('menggandakan', 1)
# ('26', 1)
# ('berhasil', 1)
# ('nahas', 1)
# ('klasemen', 1)
# ('merebut', 1)
# ('atas', 1)
# ('pekan', 1)
# ('atau', 1)
# ('lionel', 1)
# ('10', 2)
# ('karena', 1)
# ('wib', 1)
# ('bertahan', 1)
# ('ke', 2)
# ('melalui', 1)
# ('camp', 1)
# ('barcelona', 4)
# ('coutinho', 1)
# ('keluar', 1)
# ('yang', 1)
# ('pertama', 1)
# ('namun', 1)
# ('membuka', 1)
# ('seusai', 1)
# ...
